# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:////Volumes/Storage/AmbryWarehouse/mBCQm5TGwO.db")
bc = pd.read_sql_table('p03G001003_brfss_county', engine)

# %%
bc.head()
# Out:
#    c03G01001_id c03G01002_gvid  c03G01003__state  c03G01004_fmonth  \
# 0             1         0O011b                 1                 2
# 1             2         0O011b                 1                 2
# 2             3         0O011b                 1                 3
# 3             4         0O011b                 1                 1
# 4             5         0O011b                 1                 1
#
#    c03G01005_dispcode  c03G01006_seqno  c03G01007__psu  c03G01008_genhlth  \
# 0                1100       2012000039      2012000039                  5
# 1                1100       2012000061      2012000061                  1
# 2                1100       2012000080      2012000080                  5
# 3                1100       2012000234      2012000234                  3
# 4                1200       2012000276      2012000276                  2
#
#    c03G01009_physhlth  c03G0100a_menthlth       ...         \
# 0                  30                  30       ...
# ...

# %%
bc.EXERHMM2.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-84393f27c70f> in <module>()
# ----> 1 bc.EXERHMM2.unique()
#
# /Library/Python/2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1934                 return self[name]
#    1935             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1936                                  (type(self).__name__, name))
#    1937
#    1938     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'EXERHMM2'

# %%
df.c03G0102g__cnty.value_counts()
# Out:
# 37    3504
# 73    1128
# 59    1037
# 65     824
# 71     705
# 85     666
# 1      619
# 67     609
# dtype: int64
